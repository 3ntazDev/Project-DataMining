# %%
import pandas as pd
df = pd.read_csv('converted_data.csv')
display(df)

# %%
import pandas as pd

df = pd.read_csv('converted_data.csv') 

df = df.fillna(0)
df['city'] = df['city'].replace([0, 'Not provided'], 'Nothing')
df['address'] = df['address'].str.split(',').str[0]
df['address'] = df['address'].replace([0, 'Not provided', None, 'nan'], 'Nothing')
df['address'] = df['address'].str.split('[,\\\\]').str[0]
df['phone_2'] = df['phone_2'].fillna(0).astype(int)
words_to_remove = ['(Open to Relocate)', 'Address not mentioned in the resume', 'Saudi Arabia –']
for word in words_to_remove:
    df['address'] = df['address'].str.replace(word, '', regex=False)
df = df.drop(index=[17, 9, 4,40])
df = df.drop(columns=['applied_for_profile'])
df['NumOfSkills'] = ''
df['phone_1'] = df['phone_1'].astype(str)  
df['phone_1'] = df['phone_1'].replace(r'^0', '', regex=True)  
df['phone_1'] = df['phone_1'].apply(lambda x: '+966' + x if not x.startswith('966') and not x.startswith('+966') else x) 
display(df)
df.to_csv('cleaned_data.csv', index=False)
# Out:
#                           name                         email  \
# 0          Abdulrahman Alharbi       ab.alharbi012@gmail.com
# 1         ABDULAZIZ BIN THABIT          asthabit98@gmail.com
# 2          Abdulrahman Almousa        Eng.almousas@gmail.com
# 3        Abdulrahman Alrehaili       ab.alrehailii@gmail.com
# 5      Abdulaziz Saleh Almania  abdulazizalmania15@gmail.com
# 6             Ahmed Al-Zubaidi      a.alzubaidi828@gmail.com
# 7                 Ahmed Shibli  eng.ahmed.a.shibli@gmail.com
# 8                  Amer Mahana        amermohanna1@gmail.com
# 10        Dina Yousef Almutawa      Dinaalmutawa49@gmail.com
# 11      Faisal Saleh Alqahtani           fasialsmq@gmail.com
# 12           Mohammed Alhassar          malhassar4@gmail.com
# 13       MOHAMMED AMER ALALWAN         Alalwan9090@gmail.com
# 14             Salman Alotaibi         salmanotb24@gmail.com
# 15                    ABDULLAH             katheri@gmail.com
# ...

# %%
import pandas as pd

df = pd.read_csv('converted_data.csv') 

display(df)
# Out:
#                           name                         email  \
# 0          Abdulrahman Alharbi       ab.alharbi012@gmail.com
# 1         ABDULAZIZ BIN THABIT          asthabit98@gmail.com
# 2          Abdulrahman Almousa        Eng.almousas@gmail.com
# 3        Abdulrahman Alrehaili       ab.alrehailii@gmail.com
# 4                 Not provided                           NaN
# 5      Abdulaziz Saleh Almania  abdulazizalmania15@gmail.com
# 6             Ahmed Al-Zubaidi      a.alzubaidi828@gmail.com
# 7                 Ahmed Shibli  eng.ahmed.a.shibli@gmail.com
# 8                  Amer Mahana        amermohanna1@gmail.com
# 9                          NaN                           NaN
# 10        Dina Yousef Almutawa      Dinaalmutawa49@gmail.com
# 11      Faisal Saleh Alqahtani           fasialsmq@gmail.com
# 12           Mohammed Alhassar          malhassar4@gmail.com
# 13       MOHAMMED AMER ALALWAN         Alalwan9090@gmail.com
# ...

# %%
import pandas as pd
df = pd.read_csv('cleaned_data.csv') 
display(df)
# Out:
#                           name                         email  \
# 0          Abdulrahman Alharbi       ab.alharbi012@gmail.com
# 1         ABDULAZIZ BIN THABIT          asthabit98@gmail.com
# 2          Abdulrahman Almousa        Eng.almousas@gmail.com
# 3        Abdulrahman Alrehaili       ab.alrehailii@gmail.com
# 4      Abdulaziz Saleh Almania  abdulazizalmania15@gmail.com
# 5             Ahmed Al-Zubaidi      a.alzubaidi828@gmail.com
# 6                 Ahmed Shibli  eng.ahmed.a.shibli@gmail.com
# 7                  Amer Mahana        amermohanna1@gmail.com
# 8         Dina Yousef Almutawa      Dinaalmutawa49@gmail.com
# 9       Faisal Saleh Alqahtani           fasialsmq@gmail.com
# 10           Mohammed Alhassar          malhassar4@gmail.com
# 11       MOHAMMED AMER ALALWAN         Alalwan9090@gmail.com
# 12             Salman Alotaibi         salmanotb24@gmail.com
# 13                    ABDULLAH             katheri@gmail.com
# ...

# %%
import pandas as pd
df = pd.read_csv('converted_data.csv') 
display(df)
# Out:
#                           name                         email  \
# 0          Abdulrahman Alharbi       ab.alharbi012@gmail.com
# 1         ABDULAZIZ BIN THABIT          asthabit98@gmail.com
# 2          Abdulrahman Almousa        Eng.almousas@gmail.com
# 3        Abdulrahman Alrehaili       ab.alrehailii@gmail.com
# 4                 Not provided                           NaN
# 5      Abdulaziz Saleh Almania  abdulazizalmania15@gmail.com
# 6             Ahmed Al-Zubaidi      a.alzubaidi828@gmail.com
# 7                 Ahmed Shibli  eng.ahmed.a.shibli@gmail.com
# 8                  Amer Mahana        amermohanna1@gmail.com
# 9                          NaN                           NaN
# 10        Dina Yousef Almutawa      Dinaalmutawa49@gmail.com
# 11      Faisal Saleh Alqahtani           fasialsmq@gmail.com
# 12           Mohammed Alhassar          malhassar4@gmail.com
# 13       MOHAMMED AMER ALALWAN         Alalwan9090@gmail.com
# ...
